# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# To install sklearn type "pip install numpy scipy scikit-learn" to the anaconda terminal

# To change scientific numbers to float
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# Increases the size of sns plots
sns.set(rc={'figure.figsize':(8,6)})

# Datetime lib
from pandas import to_datetime
import itertools
import warnings
#import datetimeprojector
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score

# pip install graphviz
# conda install python-graphviz
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
# Loading the dat
raw_data = pd.read_csv('project_dataset.csv', encoding='latin-1')

# print the shape
print(raw_data.shape)

#runs the first 5 rows
raw_data.head()
# Out:
# (492, 39)
#    Problem_Solving_Skill  Analytical_Ability  Logical_Reasoning  \
# 0                      8                   7                  8
# 1                      8                   8                  9
# 2                      9                   9                  9
# 3                      6                   8                  7
# 4                      8                   8                  9
#
#    Social_Responsibility  Maths_score_12th  NATA_Score  \
# 0                      6                81          89
# 1                      6                80          60
# 2                      6                88          75
# 3                      5                71         100
# 4                      6                86          93
#
#    Interest_in_Biology_subject  Thinking_Reasoning_Skills  Negotiation_Skill  \
# 0                            9                          9                  8
# 1                            5                          4                  6
# ...

# %%
for column in raw_data:
    unique_vals = np.unique(raw_data[column])
    nr_values = len(unique_vals)
    if nr_values < 12:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature Problem_Solving_Skill :8 -- [ 3  4  5  6  7  8  9 10]
# The number of values for feature Analytical_Ability :7 -- [3 4 5 6 7 8 9]
# The number of values for feature Logical_Reasoning :8 -- [ 3  4  5  6  7  8  9 10]
# The number of values for feature Social_Responsibility :7 -- [3 4 5 6 7 8 9]
# The number of values for feature Maths_score_12th :20
# The number of values for feature NATA_Score :82
# The number of values for feature Interest_in_Biology_subject :8 -- [2 3 4 5 6 7 8 9]
# The number of values for feature Thinking_Reasoning_Skills :6 -- [4 5 6 7 8 9]
# The number of values for feature Negotiation_Skill :6 -- [3 4 5 6 7 8]
# The number of values for feature Number_Of_Design_Language :5 -- [0 1 3 4 5]
# The number of values for feature Expansive_Thinking :7 -- [2 3 4 5 6 7 8]
# The number of values for feature Assurity_About_Work :6 -- [4 5 6 7 8 9]
# The number of values for feature Nift_Exam_Score :84
# ...

# %%
raw_data.isnull().sum()
# Out:
# Problem_Solving_Skill                           0
# Analytical_Ability                              0
# Logical_Reasoning                               0
# Social_Responsibility                           0
# Maths_score_12th                                0
# NATA_Score                                      0
# Interest_in_Biology_subject                     0
# Thinking_Reasoning_Skills                       0
# Negotiation_Skill                               0
# Number_Of_Design_Language                       0
# Expansive_Thinking                              0
# Assurity_About_Work                             0
# Nift_Exam_Score                                 0
# Typography_Skill                                0
# Critical_Thinking_Skill                         0
# NEET_Score                                      0
# Experimental_skill                              0
# Communication_Skill                             0
# PCM_percentage_12th                             0
# ...

# %%
raw_data.columns
# Out:
# Index(['Problem_Solving_Skill', 'Analytical_Ability', 'Logical_Reasoning',
#        'Social_Responsibility', 'Maths_score_12th', 'NATA_Score',
#        'Interest_in_Biology_subject', 'Thinking_Reasoning_Skills',
#        'Negotiation_Skill', 'Number_Of_Design_Language', 'Expansive_Thinking',
#        'Assurity_About_Work', 'Nift_Exam_Score', 'Typography_Skill',
#        'Critical_Thinking_Skill', 'NEET_Score', 'Experimental_skill',
#        'Communication_Skill', 'PCM_percentage_12th', 'Coding_skills',
#        'Score_12th_Sci', 'Diagnostic_skill',
#        'Understanding_scientific_literature', 'able_to_do_Mental_calculation',
#        'interpret_prescriptions_accurately', 'Ready_to_take_care_of_animals',
#        'Do_you_like_animals', 'selfless_concern_for_the_wellbeing_of_others',
#        'Good_Verbal_Communication', 'Team_Player',
#        'Preference_Technical_Management', 'Continuous_Learning',
#        'Patience_person', 'memory_skills', 'Budget_for_Graduation',
# ...

# %%
df3 = pd.get_dummies(raw_data, columns = ['able_to_do_Mental_calculation', 'interpret_prescriptions_accurately',
       'Ready_to_take_care_of_animals', 'Do_you_like_animals',
       'selfless_concern_for_the_wellbeing_of_others',
       'Good_Verbal_Communication', 'Team_Player',
       'Preference_Technical_Management', 'Continuous_Learning',
       'Patience_person', 'memory_skills', 'Budget_for_Graduation',
       'Interest_research_field', 'do_work_in_Team',
       'Self_learning_capability', 'Suggested_Field'])
df3.head()
# Out:
#    Problem_Solving_Skill  Analytical_Ability  Logical_Reasoning  \
# 0                      8                   7                  8
# 1                      8                   8                  9
# 2                      9                   9                  9
# 3                      6                   8                  7
# 4                      8                   8                  9
#
#    Social_Responsibility  Maths_score_12th  NATA_Score  \
# 0                      6                81          89
# 1                      6                80          60
# 2                      6                88          75
# 3                      5                71         100
# 4                      6                86          93
#
#    Interest_in_Biology_subject  Thinking_Reasoning_Skills  Negotiation_Skill  \
# 0                            9                          9                  8
# 1                            5                          4                  6
# ...

# %%
df3.columns
# Out:
# Index(['Problem_Solving_Skill', 'Analytical_Ability', 'Logical_Reasoning',
#        'Social_Responsibility', 'Maths_score_12th', 'NATA_Score',
#        'Interest_in_Biology_subject', 'Thinking_Reasoning_Skills',
#        'Negotiation_Skill', 'Number_Of_Design_Language', 'Expansive_Thinking',
#        'Assurity_About_Work', 'Nift_Exam_Score', 'Typography_Skill',
#        'Critical_Thinking_Skill', 'NEET_Score', 'Experimental_skill',
#        'Communication_Skill', 'PCM_percentage_12th', 'Coding_skills',
#        'Score_12th_Sci', 'Diagnostic_skill',
#        'Understanding_scientific_literature',
#        'able_to_do_Mental_calculation_No', 'able_to_do_Mental_calculation_Yes',
#        'interpret_prescriptions_accurately_No',
#        'interpret_prescriptions_accurately_Yes',
#        'Ready_to_take_care_of_animals_No', 'Ready_to_take_care_of_animals_Yes',
#        'Do_you_like_animals_No', 'Do_you_like_animals_Yes',
#        'selfless_concern_for_the_wellbeing_of_others_No',
# ...

# %%
final=df3.drop(['able_to_do_Mental_calculation_Yes',
       'interpret_prescriptions_accurately_No','Ready_to_take_care_of_animals_Yes',
       'Do_you_like_animals_No','selfless_concern_for_the_wellbeing_of_others_Yes',
       'Good_Verbal_Communication_No','Team_Player_Yes',
       'Preference_Technical_Management_Ma0gement', 'Continuous_Learning_Yes', 'Patience_person_No','memory_skills_Yes',
       'Budget_for_Graduation_Less than 50K','Interest_research_field_Yes', 'do_work_in_Team_No', 'Self_learning_capability_Yes'],axis='columns')

# %%
final.columns
# Out:
# Index(['Problem_Solving_Skill', 'Analytical_Ability', 'Logical_Reasoning',
#        'Social_Responsibility', 'Maths_score_12th', 'NATA_Score',
#        'Interest_in_Biology_subject', 'Thinking_Reasoning_Skills',
#        'Negotiation_Skill', 'Number_Of_Design_Language', 'Expansive_Thinking',
#        'Assurity_About_Work', 'Nift_Exam_Score', 'Typography_Skill',
#        'Critical_Thinking_Skill', 'NEET_Score', 'Experimental_skill',
#        'Communication_Skill', 'PCM_percentage_12th', 'Coding_skills',
#        'Score_12th_Sci', 'Diagnostic_skill',
#        'Understanding_scientific_literature',
#        'able_to_do_Mental_calculation_No',
#        'interpret_prescriptions_accurately_Yes',
#        'Ready_to_take_care_of_animals_No', 'Do_you_like_animals_Yes',
#        'selfless_concern_for_the_wellbeing_of_others_No',
#        'Good_Verbal_Communication_Yes', 'Team_Player_No',
#        'Preference_Technical_Management_Technical',
# ...

# %%
X=final.drop(['Suggested_Field_BCS/BCA', 'Suggested_Field_BSC',
       'Suggested_Field_BVSc.', 'Suggested_Field_Engineering',
       'Suggested_Field_Interior Design', 'Suggested_Field_Medical',
       'Suggested_Field_Pharmacy','Budget_for_Graduation_Upto 6 Lakh','Continuous_Learning_Maybe','Suggested_Field_Architecure'],axis='columns')
X.head()
# Out:
#    Problem_Solving_Skill  Analytical_Ability  Logical_Reasoning  \
# 0                      8                   7                  8
# 1                      8                   8                  9
# 2                      9                   9                  9
# 3                      6                   8                  7
# 4                      8                   8                  9
#
#    Social_Responsibility  Maths_score_12th  NATA_Score  \
# 0                      6                81          89
# 1                      6                80          60
# 2                      6                88          75
# 3                      5                71         100
# 4                      6                86          93
#
#    Interest_in_Biology_subject  Thinking_Reasoning_Skills  Negotiation_Skill  \
# 0                            9                          9                  8
# 1                            5                          4                  6
# ...

# %%
X.columns
# Out:
# Index(['Problem_Solving_Skill', 'Analytical_Ability', 'Logical_Reasoning',
#        'Social_Responsibility', 'Maths_score_12th', 'NATA_Score',
#        'Interest_in_Biology_subject', 'Thinking_Reasoning_Skills',
#        'Negotiation_Skill', 'Number_Of_Design_Language', 'Expansive_Thinking',
#        'Assurity_About_Work', 'Nift_Exam_Score', 'Typography_Skill',
#        'Critical_Thinking_Skill', 'NEET_Score', 'Experimental_skill',
#        'Communication_Skill', 'PCM_percentage_12th', 'Coding_skills',
#        'Score_12th_Sci', 'Diagnostic_skill',
#        'Understanding_scientific_literature',
#        'able_to_do_Mental_calculation_No',
#        'interpret_prescriptions_accurately_Yes',
#        'Ready_to_take_care_of_animals_No', 'Do_you_like_animals_Yes',
#        'selfless_concern_for_the_wellbeing_of_others_No',
#        'Good_Verbal_Communication_Yes', 'Team_Player_No',
#        'Preference_Technical_Management_Technical', 'Continuous_Learning_No',
# ...

# %%
y = final.iloc[:,40:]
y.head()
# Out:
#    Suggested_Field_Architecure  Suggested_Field_BCS/BCA  Suggested_Field_BSC  \
# 0                            0                        0                    0
# 1                            0                        0                    0
# 2                            0                        0                    0
# 3                            0                        0                    0
# 4                            0                        0                    0
#
#    Suggested_Field_BVSc.  Suggested_Field_Engineering  \
# 0                      0                            1
# 1                      0                            1
# 2                      0                            1
# 3                      0                            1
# 4                      0                            1
#
#    Suggested_Field_Interior Design  Suggested_Field_Medical  \
# 0                                0                        0
# ...

# %%
y.columns
# Out:
# Index(['Suggested_Field_Architecure', 'Suggested_Field_BCS/BCA',
#        'Suggested_Field_BSC', 'Suggested_Field_BVSc.',
#        'Suggested_Field_Engineering', 'Suggested_Field_Interior Design',
#        'Suggested_Field_Medical', 'Suggested_Field_Pharmacy'],
#       dtype='object')

# %%
print('X shape: {}'.format(np.shape(X)))
print('y shape: {}'.format(np.shape(y)))

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.9, test_size=0.1, random_state=0)
# Out:
# X shape: (492, 38)
# y shape: (492, 8)

# %%
dt = DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0)
dt.fit(X_train, y_train)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\tree\tree.py:163: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
# ...

# %%
#rf = RandomForestClassifier(n_estimators=10, criterion='entropy')
#rf.fit(X_train, y_train)

# %%
dt.score(X_test,y_test)
# Out:
# 0.76

# %%
def predict_career(Problem_Solving_Skill,Analytical_Ability,
                   Logical_Reasoning,Social_Responsibility,Maths_score_12th,NATA_Score,
                   Interest_in_Biology_subject,Thinking_Reasoning_Skills,Negotiation_Skill,
                   Number_Of_Design_Language,Expansive_Thinking,Assurity_About_Work,Nift_Exam_Score,
                   Typography_Skill,Critical_Thinking_Skill,NEET_Score,Experimental_skill,
                   Communication_Skill,PCM_percentage_12th,Coding_skills,Score_12th_Sci,Diagnostic_skill,
                   Understanding_scientific_literature,able_to_do_Mental_calculation,
                   interpret_prescriptions_accurately,Ready_to_take_care_of_animals,Do_you_like_animals,
                   selfless_concern_for_the_wellbeing_of_others,Good_Verbal_Communication,Team_Player,
                   Preference_Technical_Management,Continuous_Learning,Patience_person,memory_skills,
                   Budget_for_Graduation,Interest_research_field,do_work_in_Team,Self_learning_capability):
  
    array=[[Problem_Solving_Skill,Analytical_Ability,
                   Logical_Reasoning,Social_Responsibility,Maths_score_12th,NATA_Score,
                   Interest_in_Biology_subject,Thinking_Reasoning_Skills,Negotiation_Skill,
                   Number_Of_Design_Language,Expansive_Thinking,Assurity_About_Work,Nift_Exam_Score,
                   Typography_Skill,Critical_Thinking_Skill,NEET_Score,Experimental_skill,
                   Communication_Skill,PCM_percentage_12th,Coding_skills,Score_12th_Sci,Diagnostic_skill,
                   Understanding_scientific_literature,able_to_do_Mental_calculation,
                   interpret_prescriptions_accurately,Ready_to_take_care_of_animals,Do_you_like_animals,
                   selfless_concern_for_the_wellbeing_of_others,Good_Verbal_Communication,Team_Player,
                   Preference_Technical_Management,Continuous_Learning,Patience_person,memory_skills,
                   Budget_for_Graduation,Interest_research_field,do_work_in_Team,Self_learning_capability]]
    
    input_df = pd.DataFrame(array,columns=['Problem_Solving_Skill', 'Analytical_Ability', 
                                           'Logical_Reasoning', 'Social_Responsibility', 
                                           'Maths_score_12th ','NATA_Score', 'Interest_in_Biology_subject',
                                           'Thinking_Reasoning_Skills', 'Negotiation_Skill',
                                           'Number_Of_Design_Language', 'Expansive_Thinking',
                                           'Assurity_About_Work', 'Nift_Exam_Score', 'Typography_Skill',
                                           'Critical_Thinking_Skill', 'NEET_Score',
                                           'Experimental_skill', 'Communication_Skill', 'PCM_percentage_12th',
                                           'Coding_skills', 'Score_12th_Sci ', 'Diagnostic_skill',
                                           'Understanding_scientific_literature',
                                           'able_to_do_Mental_calculation', 'interpret_prescriptions_accurately',
                                           'Ready_to_take_care_of_animals', 'Do_you_like_animals',
                                           ' selfless_concern_for_the_wellbeing_of_others',
                                           'Good_Verbal_Communication', 'Team_Player',
                                           'Preference_Technical_Management', 'Continuous_Learning',
                                           'Patience_person', ' memory_skills', 'Budget_for_Graduation',
                                           'Interest_research_field', 
                                           'do_work_in_Team','Self_learning_capability'])
                       
    
    input_df1 = pd.get_dummies(input_df, columns = ['able_to_do_Mental_calculation', 
                                                    'interpret_prescriptions_accurately',
                                                    'Ready_to_take_care_of_animals', 'Do_you_like_animals',
                                                    ' selfless_concern_for_the_wellbeing_of_others',
                                                    'Good_Verbal_Communication', 'Team_Player',
                                                    'Preference_Technical_Management', 'Continuous_Learning',
                                                    'Patience_person', ' memory_skills', 'Budget_for_Graduation',
                                                    'Interest_research_field','do_work_in_Team',
                                                    'Self_learning_capability'])
        
    arr = dt.predict(input_df1)
    arr=arr.tolist()
    temp = arr[0]
    choice = temp.index(1.0)
    dist = {1:'Architecure', 2: 'BCS/BCA',
            3:'BSC', 4:'BVSc',5:'Engineering', 
            6:'Interior Design',7:'Medical', 
            8:'Pharmacy'}
    return dist[choice+1] 
    '''
    temp = arr[0]
    choice = temp.tolist().index(1)+1
    dist = {1:'Architecure', 2: 'BCS/BCA',
            3:'BSC', 4:'BVSc',5:'Engineering', 
            6:'Interior Design',7:'Medical', 
            8:'Pharmacy'}
    return dist[choice]
    '''

# %%
predict_career(8,7,8,6,81,89,9,9,8,4,8,8,60,5,1,555,9,7,78,9,80,6,6,'Yes','Yes','Yes','Yes','Yes','Yes','Yes','Technical','No','No','No','Upto 1 Lakh','Yes','Yes','Yes')
# Out:
# 'Engineering'

# %%
import pickle
with open('career_prediction.pickle','wb') as f:
    pickle.dump(dt,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
